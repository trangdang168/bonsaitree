# %%
import pandas as pd
druid_file = "/homes/thdang/trang_amish/bonsai_results/toy_test.csv"
df = pd.read_csv(druid_file)

# %%
df.loc
# Out:
#     Unnamed: 0                     real                    druid  ca1  ca2  \
# 0            0  {-22: {-13: 3, -17: 3}}  {-18: {-13: 3, -17: 3}}  -13  -17
# 1            1  {-21: {-13: 3, -17: 3}}  {-18: {-13: 3, -17: 3}}  -13  -17
# 2            2  {-29: {-13: 1, -15: 1}}  {-16: {-13: 3, -15: 3}}  -13  -15
# 3            3  {-10: {-13: 1, -15: 1}}  {-16: {-13: 3, -15: 3}}  -13  -15
# 4            4  {-29: {-13: 1, -16: 1}}  {-17: {-13: 2, -16: 3}}  -13  -16
# 5            5  {-10: {-13: 1, -16: 1}}  {-17: {-13: 2, -16: 3}}  -13  -16
# 6            6  {-23: {-13: 2, -28: 1}}  {-29: {-13: 2, -28: 3}}  -13  -28
# 7            7  {-29: {-13: 1, -29: 0}}  {-30: {-13: 3, -29: 3}}  -13  -29
# 8            8  {-22: {-17: 3, -16: 3}}  {-18: {-17: 4, -16: 4}}  -17  -16
# 9            9  {-21: {-17: 3, -16: 3}}  {-18: {-17: 4, -16: 4}}  -17  -16
# 10          10  {-22: {-17: 3, -28: 2}}  {-29: {-17: 4, -28: 4}}  -17  -28
# 11          11  {-21: {-17: 3, -28: 2}}  {-29: {-17: 4, -28: 4}}  -17  -28
# 12          12  {-29: {-15: 1, -16: 1}}  {-17: {-15: 4, -16: 4}}  -15  -16
# 13          13  {-10: {-15: 1, -16: 1}}  {-17: {-15: 4, -16: 4}}  -15  -16
# 14          14  {-23: {-15: 2, -28: 1}}  {-29: {-15: 4, -28: 4}}  -15  -28
# 15          15  {-22: {-17: 3, -29: 2}}  {-30: {-17: 3, -29: 3}}  -17  -29
# 16          16  {-21: {-17: 3, -29: 2}}  {-30: {-17: 3, -29: 3}}  -17  -29
# 17          17  {-29: {-15: 1, -29: 0}}  {-30: {-15: 3, -29: 3}}  -15  -29
# 18          18  {-29: {-16: 1, -29: 0}}  {-30: {-16: 3, -29: 3}}  -16  -29
# 19          19  {-23: {-28: 1, -29: 1}}  {-30: {-28: 3, -29: 3}}  -28  -29
#
#     real_root_id  real_adj1  real_adj2  fake_adj1  fake_adj2 ca1_thread_id  \
# 0            -22          3          3          3          3             b
# 1            -21          3          3          3          3             b
# 2            -29          1          1          3          3             b
# 3            -10          1          1          3          3             b
# 4            -29          1          1          2          3             b
# 5            -10          1          1          2          3             b
# 6            -23          2          1          2          3             b
# 7            -29          1          0          3          3             b
# 8            -22          3          3          4          4             f
# 9            -21          3          3          4          4             f
# 10           -22          3          2          4          4             f
# 11           -21          3          2          4          4             f
# 12           -29          1          1          4          4             c
# 13           -10          1          1          4          4             c
# 14           -23          2          1          4          4             c
# 15           -22          3          2          3          3             f
# 16           -21          3          2          3          3             f
# 17           -29          1          0          3          3             c
# 18           -29          1          0          3          3             d
# 19           -23          1          1          3          3             e
#
#    ca2_thread_id real_root_thread_id
# 0              f                   q
# 1              f                   p
# 2              c                   h
# 3              c                   g
# 4              d                   h
# 5              d                   g
# 6              e                   l
# 7              h                   h
# 8              d                   q
# 9              d                   p
# 10             e                   q
# 11             e                   p
# 12             d                   h
# 13             d                   g
# 14             e                   l
# 15             h                   q
# 16             h                   p
# 17             h                   h
# 18             h                   h
# 19             h                   l

# %%
df = df[['real_root_thread_id', 'ca1_thread_id', 'fake_adj1', 'real_adj1',
       'ca2_thread_id', 'fake_adj2', 'real_adj2']]
df["code"] = df["real_root_thread_id"] + ":" + df["ca1_thread_id"] + "-" + df["ca2_thread_id"]
# Out:
# /homes/thdang/trang_amish/env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#    real_root_thread_id ca1_thread_id  fake_adj1  real_adj1 ca2_thread_id  \
# 0                    q             b          3          3             f
# 1                    p             b          3          3             f
# 2                    h             b          3          1             c
# 3                    g             b          3          1             c
# 4                    h             b          2          1             d
# 5                    g             b          2          1             d
# 6                    l             b          2          2             e
# 7                    h             b          3          1             h
# 8                    q             f          4          3             d
# 9                    p             f          4          3             d
# 10                   q             f          4          3             e
# 11                   p             f          4          3             e
# 12                   h             c          4          1             d
# 13                   g             c          4          1             d
# 14                   l             c          4          2             e
# 15                   q             f          3          3             h
# 16                   p             f          3          3             h
# 17                   h             c          3          1             h
# 18                   h             d          3          1             h
# 19                   l             e          3          1             h
#
#     fake_adj2  real_adj2   code
# 0           3          3  q:b-f
# 1           3          3  p:b-f
# 2           3          1  h:b-c
# 3           3          1  g:b-c
# 4           3          1  h:b-d
# 5           3          1  g:b-d
# 6           3          1  l:b-e
# 7           3          0  h:b-h
# 8           4          3  q:f-d
# 9           4          3  p:f-d
# 10          4          2  q:f-e
# 11          4          2  p:f-e
# 12          4          1  h:c-d
# 13          4          1  g:c-d
# 14          4          1  l:c-e
# 15          3          2  q:f-h
# 16          3          2  p:f-h
# 17          3          0  h:c-h
# 18          3          0  h:d-h
# 19          3          1  l:e-h

# %%
df.loc[0]
# Out:
# Unnamed: 0                                   0
# real                   {-22: {-13: 3, -17: 3}}
# druid                  {-18: {-13: 3, -17: 3}}
# ca1                                        -13
# ca2                                        -17
# real_root_id                               -22
# real_adj1                                    3
# real_adj2                                    3
# fake_adj1                                    3
# fake_adj2                                    3
# ca1_thread_id                                b
# ca2_thread_id                                f
# real_root_thread_id                          q
# Name: 0, dtype: object
